# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   299.000000     299.000000     299.000000     299.000000  299.000000
# mean   2013.615385       4.589632       7.541037   36916.752508    0.043478
# std       2.896868       4.984240       8.567887   39015.170352    0.248720
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.850000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.510000       6.100000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.840000   48883.500000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df['Seller_Type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
df['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df['Car_Name'].unique()
# Out:
# array(['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
#        's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis',
#        '800', 'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
#        'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
#        'camry', 'land cruiser', 'Royal Enfield Thunder 500',
#        'UM Renegade Mojave', 'KTM RC200', 'Bajaj Dominar 400',
#        'Royal Enfield Classic 350', 'KTM RC390', 'Hyosung GT250R',
#        'Royal Enfield Thunder 350', 'KTM 390 Duke ',
#        'Mahindra Mojo XT300', 'Bajaj Pulsar RS200',
#        'Royal Enfield Bullet 350', 'Royal Enfield Classic 500',
#        'Bajaj Avenger 220', 'Bajaj Avenger 150', 'Honda CB Hornet 160R',
#        'Yamaha FZ S V 2.0', 'Yamaha FZ 16', 'TVS Apache RTR 160',
#        'Bajaj Pulsar 150', 'Honda CBR 150', 'Hero Extreme',
#        'Bajaj Avenger 220 dtsi', 'Bajaj Avenger 150 street',
# ...

# %%
sns.regplot(y='Kms_Driven',x='Selling_Price',data=df)
plt.show()

# %%
df.groupby('Owner')['Kms_Driven'].mean()
# Out:
# Owner
# 0     36749.184028
# 1     31234.400000
# 3    142000.000000
# Name: Kms_Driven, dtype: float64

# %%
df.groupby('Transmission')['Selling_Price'].mean()
# Out:
# Transmission
# Automatic    9.071795
# Manual       3.917308
# Name: Selling_Price, dtype: float64

# %%
df.groupby('Owner')['Selling_Price'].mean()
# Out:
# Owner
# 0    4.687847
# 1    1.970000
# 3    2.500000
# Name: Selling_Price, dtype: float64

# %%
df.groupby('Owner')['Car_Name'].count()
# Out:
# Owner
# 0    288
# 1     10
# 3      1
# Name: Car_Name, dtype: int64

# %%
df.groupby('Car_Name')['Selling_Price'].mean()
# Out:
# Car_Name
# 800                  0.350000
# Activa 3g            0.310000
# Activa 4g            0.400000
# Bajaj  ct 100        0.180000
# Bajaj Avenger 150    0.750000
#                        ...
# sx4                  3.158333
# verna                6.107857
# vitara brezza        9.250000
# wagon r              2.512500
# xcent                4.966667
# Name: Selling_Price, Length: 98, dtype: float64

# %%
df.groupby(['Fuel_Type','Transmission'])['Selling_Price'].mean()
# Out:
# Fuel_Type  Transmission
# CNG        Manual           3.100000
# Diesel     Automatic       20.490000
#            Manual           7.671702
# Petrol     Automatic        4.586071
#            Manual           3.088768
# Name: Selling_Price, dtype: float64

# %%
df[df['Fuel_Type']=='CNG'].groupby('Transmission').count()
# Out:
#               Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# Transmission
# Manual               2     2              2              2           2
#
#               Fuel_Type  Seller_Type  Owner
# Transmission
# Manual                2            2      2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       299 non-null    object
#  1   Year           299 non-null    int64
#  2   Selling_Price  299 non-null    float64
#  3   Present_Price  299 non-null    float64
#  4   Kms_Driven     299 non-null    int64
#  5   Fuel_Type      299 non-null    object
#  6   Seller_Type    299 non-null    object
#  7   Transmission   299 non-null    object
#  8   Owner          299 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 23.4+ KB

# %%
sns.lineplot(y='Selling_Price',x='Year',data=df)
# Out:
# C:\Users\aniru\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\aniru\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Year', ylabel='Selling_Price'>

# %%
sns.lineplot(x='Year',y='Present_Price',data=df)
# Out:
# C:\Users\aniru\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\aniru\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Year', ylabel='Present_Price'>

# %%
df['Current_Year']=2020

# %%
df['no_of_years']=df['Current_Year']-df['Year']

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Current_Year  no_of_years
# 0      Dealer       Manual      0          2020            6
# 1      Dealer       Manual      0          2020            7
# 2      Dealer       Manual      0          2020            3
# 3      Dealer       Manual      0          2020            9
# 4      Dealer       Manual      0          2020            6

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Current_Year
# 0      Dealer       Manual      0          2020
# 1      Dealer       Manual      0          2020
# 2      Dealer       Manual      0          2020
# 3      Dealer       Manual      0          2020
# 4      Dealer       Manual      0          2020

# %%
sns.regplot(x='Present_Price',y='Selling_Price',data=df,color='green')
plt.show()

# %%
sns.regplot(x='no_of_years',y='Selling_Price',data=df,color='brown',marker=True,)
plt.show()

# %%
df.groupby('no_of_years')['Selling_Price'].mean()
# Out:
# no_of_years
# 2     9.250000
# 3     6.209143
# 4     5.161429
# 5     5.642500
# 6     4.762105
# 7     3.540909
# 8     3.841304
# 9     2.375263
# 10    5.262667
# 11    2.816667
# 12    1.002857
# 13    0.160000
# 14    1.437500
# 15    2.487500
# 16    1.500000
# 17    1.300000
# Name: Selling_Price, dtype: float64

# %%
df.groupby('no_of_years')['Car_Name'].count()
# Out:
# no_of_years
# 2      1
# 3     35
# 4     49
# 5     60
# 6     38
# 7     33
# 8     23
# 9     19
# 10    15
# 11     6
# 12     7
# 13     2
# 14     4
# 15     4
# 16     1
# 17     2
# Name: Car_Name, dtype: int64

# %%
df.drop('Year',axis=1,inplace=True)

# %%
from sklearn import preprocessing

# %%
le=preprocessing.LabelEncoder()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 300
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       299 non-null    object
#  1   Selling_Price  299 non-null    float64
#  2   Present_Price  299 non-null    float64
#  3   Kms_Driven     299 non-null    int64
#  4   Fuel_Type      299 non-null    object
#  5   Seller_Type    299 non-null    object
#  6   Transmission   299 non-null    object
#  7   Owner          299 non-null    int64
#  8   Current_Year   299 non-null    int64
#  9   no_of_years    299 non-null    int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 25.7+ KB

# %%
df['Fuel_Type']=le.fit_transform(df['Fuel_Type'])
df['Fuel_Type'].unique()
# Out:
# array([2, 1, 0])

# %%
df['Seller_Type']=le.fit_transform(df['Seller_Type'])

# %%
df['Seller_Type'].unique()
# Out:
# array([0, 1])

# %%
df['Transmission']=le.fit_transform(df['Transmission'])

# %%
df['Transmission'].unique()
# Out:
# array([1, 0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 300
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       299 non-null    object
#  1   Selling_Price  299 non-null    float64
#  2   Present_Price  299 non-null    float64
#  3   Kms_Driven     299 non-null    int64
#  4   Fuel_Type      299 non-null    int32
#  5   Seller_Type    299 non-null    int32
#  6   Transmission   299 non-null    int32
#  7   Owner          299 non-null    int64
#  8   Current_Year   299 non-null    int64
#  9   no_of_years    299 non-null    int64
# dtypes: float64(2), int32(3), int64(4), object(1)
# memory usage: 22.2+ KB

# %%
df['Car_Name']=le.fit_transform(df['Car_Name'])

# %%
df.drop('Current_Year',axis=1,inplace=True)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,cmap='viridis',linecolor='black',linewidths=0.98)
# Out:
# <Axes: >

# %%
X=df.drop('Selling_Price',axis=1)
y=df['Selling_Price']

# %%
X
# Out:
#      Car_Name  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0          90           5.59       27000          2            0
# 1          93           9.54       43000          1            0
# 2          68           9.85        6900          2            0
# 3          96           4.15        5200          2            0
# 4          92           6.87       42450          1            0
# ..        ...            ...         ...        ...          ...
# 296        69          11.60       33988          1            0
# 297        66           5.90       60000          2            0
# 298        69          11.00       87934          2            0
# 299        69          12.50        9000          1            0
# 300        66           5.90        5464          2            0
#
#      Transmission  Owner  no_of_years
# 0               1      0            6
# 1               1      0            7
# 2               1      0            3
# ...

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 299, dtype: float64

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(8).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(criterion='mse')
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1500, num = 16)]
print(n_estimators)
# Out:
# [100, 193, 286, 380, 473, 566, 660, 753, 846, 940, 1033, 1126, 1220, 1313, 1406, 1500]

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1500, num = 20)]
# Number of features to consider at every split
max_features = ['sqrt','log2']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 8, 10, 15, 50, 75]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 9,16]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 173, 247, 321, 394, 468, 542, 615, 689, 763, 836, 910, 984, 1057, 1131, 1205, 1278, 1352, 1426, 1500], 'max_features': ['sqrt', 'log2'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 8, 10, 15, 50, 75], 'min_samples_leaf': [1, 2, 5, 9, 16]}

# %%
rf = RandomForestRegressor()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=75, n_estimators=836; total time=   0.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=75, n_estimators=836; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=75, n_estimators=836; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=75, n_estimators=836; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=75, n_estimators=836; total time=   0.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 100,
#  'min_samples_split': 5,
#  'min_samples_leaf': 2,
#  'max_features': 'log2',
#  'max_depth': 5}

# %%
rf_random.best_score_
# Out:
# -5.240270466159651

# %%
predictions=rf_random.predict(X_test)

# %%
sns.distplot(y_test-predictions)
# Out:
# C:\Users\aniru\AppData\Local\Temp\ipykernel_19772\2139723301.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-predictions)
# C:\Users\aniru\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Selling_Price', ylabel='Density'>

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.9222726539185847
# MSE: 3.2916350233495626
# RMSE: 1.8142863675146663

# %%
import pickle
# open a file, where you ant to store the data
file = open('random_forest_regression_model.pkl', 'wb')
pickle.dump(rf_random, file)
