# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %% [markdown]
# DISTPLOT

# %%
#distribution of age
sns.distplot(df['Age'])
# Out:
# <ipython-input-5-67856ec52f27>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(df['Age'])

# %% [markdown]
# OBSERVATIONS FROM DISPLOT:
# 30 IS MIN AGE.
# 70 IS MAX AGE.

# %% [markdown]
# MOST OF THEM ARE AT AGE OF 40 TO 70.

# %%
#HISTOGRAM
sns.distplot(df['Age'],hist=True,rug=True)
# Out:
# <ipython-input-7-90456f229625>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],hist=True,rug=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'],bins=15)
# Out:
# <ipython-input-8-e007943ba60d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],bins=15)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['RestingBP'],kde=True,color='green')
# Out:
# <ipython-input-9-8f418ce2c3ac>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'],kde=True,color='green')
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %% [markdown]
# FROM ABOVE, 90% ARE HAVING BP IN RANGE 100 TO 150

# %% [markdown]
# PIE CHART: LESS NO OF CATEGORIES

# %%
df.groupby('Sex').size().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
#chestpain

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.groupby('ChestPainType').size().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
df.groupby('RestingECG').size().plot(kind='pie',autopct='%1.1f%%')
#ST means ST-T wave abnormality
#LVH means left ventricular hypertrophy
# Out:
# <Axes: >

# %%
df.groupby('HeartDisease').size().plot(kind='pie',autopct='%1.1f%%')
#1 means having disease
#0 is not having
# Out:
# <Axes: >

# %% [markdown]
# Violin Plot: used for analysing multiple columns

# %%
sns.violinplot(df['Age'])
# Out:
# <Axes: >

# %%
sns.violinplot(y=df['Sex'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(y=df['Age'],x=df['HeartDisease'])
#So average age of person having heart disease is 55-60 and average age not having is 50-55 yearS
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(x=df['HeartDisease'],y=df['RestingBP'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='RestingBP'>

# %%
sns.violinplot(x=df['HeartDisease'],y=df['Cholesterol'])
#here when cholestrol is 0 we see more people have disease and when cholesterol is maximum like between 100 to 350 we see the persons having non-heart disease more
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %% [markdown]
# CORRELATION AND HEATMAP

# %%
df.corr()
# Out:
# <ipython-input-21-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# ...

# %% [markdown]
# CORRELATION: 0 MEANS NO RELATION
#              -VS MEANS ONE VALUE INCREASES AS OTHER DECREASES

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-22-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# JOINTPLOT

# %%
sns.jointplot(x='Age',y='MaxHR',data=df)

# %%
sns.jointplot(x='Age',y='Age',data=df)

# %%
sns.jointplot(x='HeartDisease',y='Oldpeak',data=df)
#Almost no correlation

# %%
sns.jointplot(x='Cholesterol',y='MaxHR',data=df)

# %%
sns.jointplot(x='Age',y='MaxHR',data=df,kind='hex')

# %%
sns.jointplot(x='Age',y='MaxHR',data=df,kind='reg')

# %% [markdown]
# #as age increases MaxHR decreases

# %%
sns.jointplot(x='Cholesterol',y='FastingBS',data=df,kind='reg')

# %%
sns.jointplot(x='HeartDisease',y='MaxHR',data=df,kind='reg')

# %% [markdown]
# #IN the side we see rectangles plot which represent densities it shows HD==1 more number then HD==0.

# %%
sns.pairplot(data=df)
