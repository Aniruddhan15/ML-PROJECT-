# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.shape
# Out:
# (768, 9)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# #NO NULL VALUES

# %%
df.head(30)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %% [markdown]
# We see there are patients with Bp's and skin thickness 0
# which is imbalanced

# %% [markdown]
# WE ANALYZE BP

# %%
sns.distplot(df['BloodPressure'])
# Out:
# <ipython-input-11-6c56b1065eb4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BloodPressure'])
# <Axes: xlabel='BloodPressure', ylabel='Density'>

# %% [markdown]
# KEY NOTES:
# categorical is mode
# numerical (skewed = median)
#           (symmetric = mean)

# %%
#median to be used to OUTLIER REMOVAL as MEDIAN is robust to outliers

# %%
#here the bp is somehwat symmetric, hence we replcae the 0's with numeric mean value
df['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].mean())

# %%
df['BloodPressure'].head(10)
# Out:
# 0    72.000000
# 1    66.000000
# 2    64.000000
# 3    66.000000
# 4    40.000000
# 5    74.000000
# 6    50.000000
# 7    69.105469
# 8    70.000000
# 9    96.000000
# Name: BloodPressure, dtype: float64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      72.254807      20.536458   79.799479
# std       3.369578   31.972618      12.115932      15.952218  115.244002
# min       0.000000    0.000000      24.000000       0.000000    0.000000
# 25%       1.000000   99.000000      64.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# #INSULIN HAS SKEWED TYPE OF DISTRIBUTION, HENCE REPLCAE 0'S WITH MEDIAN

# %%
df['Insulin']=df['Insulin'].replace(0,df['Insulin'].median())

# %%
df['Insulin']
# Out:
# 0       30.5
# 1       30.5
# 2       30.5
# 3       94.0
# 4      168.0
#        ...
# 763    180.0
# 764     30.5
# 765    112.0
# 766     30.5
# 767     30.5
# Name: Insulin, Length: 768, dtype: float64

# %% [markdown]
# **DATA IMBALANCING**

# %% [markdown]
# **In Classificsation type of learning,We need to make sure the 2 target unique values that is 0 and 1 shoudl be in ratio 50:50**

# %%
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# ratio of 0:1 is 500:268, if we dont rectify this and send our data, then the model will be Biased towards generating outcome '0'.

# %% [markdown]
# Hence we need to handle this imbalance in the dataset
# Technique to handle
# 1) Oversampling: increase 268 to 500
# 2)Undersampling : decrease the samples, like decrease 0 to 268

# %% [markdown]
# #When to use Oversampling and undersampling.
# #1) Intuition to use Oversampling:

# %% [markdown]
# BoxPlot - to detect the outliers

# %%
fig,ax=plt.subplots(figsize=(15,15))
sns.boxplot(data=df,ax=ax)
plt.savefig('boxplot.jpg')

# %%
#insulin has huge no of outliers
#lower whisker/low limit = q1-1.5*IQR
#upper whisker/up limit = q3+1.5*IQR
#IQR=q3-q1

# %% [markdown]
# Split input and target features

# %%
x=df.drop(columns='Outcome',axis=1)
y=df['Outcome']

# %%
x.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Coefficient correlation among features

# %%
x.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.208984      -0.081672
# Glucose                      0.129459  1.000000       0.218579       0.057328
# BloodPressure                0.208984  0.218579       1.000000       0.020924
# SkinThickness               -0.081672  0.057328       0.020924       1.000000
# Insulin                     -0.055697  0.355252      -0.022049       0.397161
# BMI                          0.017683  0.221071       0.242656       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.000371       0.183928
# Age                          0.544341  0.263514       0.326740      -0.113970
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.055697  0.017683                 -0.033523
# Glucose                   0.355252  0.221071                  0.137337
# ...

# %%
sns.heatmap(x.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Since all features are correlated very less with each other and there is no such high correlation hence no need to remove any feature

# %% [markdown]
# Normalisation: normalising values of columns which have different ranges like pregnancies and glucose column

# %% [markdown]
# #2 type of scaling
# #1) min-max scalar
# #2) std scalar

# %% [markdown]
# ### **why**  we need to normalise?
# #for example age will be between 1-100 while population will be like in billions and trillions.This creates biasing of model as it biases towards Higher values Hence for giving equal importance to all features in same way there is need of normalisaing and scaling

# %% [markdown]
# **Note:
# standard normalisation is converting to have in terms of standard normal forms**
# #Simply, in std normal form mean is 0 and std = 1

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
x_scaled = pd.DataFrame(x_scaled)

# %%
x_scaled.describe()
# Out:
#                   0             1             2             3             4  \
# count  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02
# mean  -6.476301e-17 -9.251859e-18  1.156482e-17  1.006140e-16  2.602085e-17
# std    1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00
# min   -1.141852e+00 -3.783654e+00 -3.985352e+00 -1.288212e+00 -7.646304e-01
# 25%   -8.448851e-01 -6.852363e-01 -6.817623e-01 -1.288212e+00 -6.082010e-01
# 50%   -2.509521e-01 -1.218877e-01 -2.104440e-02  1.545332e-01 -6.010905e-01
# 75%    6.399473e-01  6.057709e-01  6.396735e-01  7.190857e-01  3.090444e-01
# max    3.906578e+00  2.444478e+00  4.108443e+00  4.921866e+00  7.123206e+00
#
#                   5             6             7
# count  7.680000e+02  7.680000e+02  7.680000e+02
# mean   2.590520e-16  2.451743e-16  1.931325e-16
# std    1.000652e+00  1.000652e+00  1.000652e+00
# min   -4.060474e+00 -1.189553e+00 -1.041549e+00
# ...

# %%
sns.boxplot(data=x_scaled)
#We note that every particular feature are of equal level much better than b4.
# Out:
# <Axes: >
